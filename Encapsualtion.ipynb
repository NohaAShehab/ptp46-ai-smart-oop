# %% [markdown]
# # Encapsulation in Python
#
# This notebook covers encapsulation concepts in Python, including:
# - Access modifiers (public, protected, private)
# - Name mangling for private attributes
# - Getters and setters
# - Properties using `@property` decorator

# %%
"""
    no access modifiers

    python ??
    function/variable
    name ==> start [a-z] ==> Public
        ==> start with _ ==> protected
        ==> start with __ ==> private

"""

# %% [markdown]
# ## Access Modifiers in Python
#
# Python uses naming conventions for access control:
# - **Public**: Names starting with letters (a-z) - accessible from anywhere
# - **Protected**: Names starting with `_` (single underscore) - should not be accessed from outside (convention)
# - **Private**: Names starting with `__` (double underscore) - name mangling occurs, making them harder to access

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.__salary = salary

emp = Employee('noha', 'n@iti.com', 2894892)

# %%
print(emp.name) # public
# Out:
# noha

# %% [markdown]
# ## Name Mangling
#
# When you use `__` (double underscore), Python performs name mangling, changing the attribute name to `_ClassName__attributeName`. This makes it harder (but not impossible) to access from outside the class.

# %%
print(emp._email) # Access to a protected member _email of a class

# ethically don't do that

emp._city = "Cairo"
# Out:
# n@iti.com

# %%
# what about private
print(emp.__salary)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 # what about private
# ----> 2 print(emp.__salary)
#
# AttributeError: 'Employee' object has no attribute '__salary'

# %%
print(emp.location)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(emp.location)
#
# AttributeError: 'Employee' object has no attribute 'location'

# %% [markdown]
# ## Encapsulation with Getters and Setters
#
# To properly encapsulate data, we use getter and setter methods to control access to private attributes and add validation logic.

# %%
print(emp.__dict__)
# Out:
# {'name': 'noha', '_email': 'n@iti.com', '_Employee__salary': 2894892, '_city': 'Cairo'}

# %%
# _Employee__salary  # scope binding
print(emp._Employee__salary)  # ethically don't do that
# Out:
# 2894892

# %%
"""
 we need encapsulation
 -> limit accessibility
 -> apply condition : salary must be int,
"""

class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.__salary = salary # private ??

    def get_salary(self):
        return  self.__salary * .9


    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError('Salary must be integer and > 0')

emp = Employee('noha', 'n@iti.com', 2894892)

print(emp.get_salary())
# Out:
# 2605402.8000000003

# %%
emp.set_salary("iti")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 emp.set_salary("iti")
#
# Cell In[10], line 21, in Employee.set_salary(self, salary)
#      19     self.__salary = salary
#      20 else:
# ---> 21     raise ValueError('Salary must be integer and > 0')
#
# ValueError: Salary must be integer and > 0

# %%
emp2 = Employee("Ali", "ali@gmail.com", "newsalary")

# %%
print(emp2.get_salary())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(emp2.get_salary())
#
# Cell In[10], line 14, in Employee.get_salary(self)
#      13 def get_salary(self):
# ---> 14     return  self.__salary * .9
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# ## Properties with `@property` Decorator
#
# The `@property` decorator allows us to define methods that can be accessed like attributes, providing a cleaner interface while maintaining encapsulation. We can also define setters using `@property_name.setter`.

# %%
"""
 we need encapsulation
 -> limit accessibility
 -> apply condition : salary must be int,
"""

class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError('Salary must be integer and > 0')

    def get_salary(self):
        return  self.__salary * .9


    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError('Salary must be integer and > 0')

emp = Employee('noha', 'n@iti.com', "wriower")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 26
#      23         else:
#      24             raise ValueError('Salary must be integer and > 0')
# ---> 26 emp = Employee('noha', 'n@iti.com', "wriower")
#
# Cell In[14], line 14, in Employee.__init__(self, name, email, salary)
#      12     self.__salary = salary
#      13 else:
# ---> 14     raise ValueError('Salary must be integer and > 0')
#
# ValueError: Salary must be integer and > 0

# %%
"""
 we need encapsulation
 -> limit accessibility
 -> apply condition : salary must be int,
"""

class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.set_salary(salary)

    def get_salary(self):
        return  self.__salary * .9


    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError('Salary must be integer and > 0')

emp = Employee('noha', 'n@iti.com', "wriower")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 23
#      20         else:
#      21             raise ValueError('Salary must be integer and > 0')
# ---> 23 emp = Employee('noha', 'n@iti.com', "wriower")
#
# Cell In[15], line 11, in Employee.__init__(self, name, email, salary)
#       9 self.name = name
#      10 self._email = email
# ---> 11 self.set_salary(salary)
#
# Cell In[15], line 21, in Employee.set_salary(self, salary)
#      19     self.__salary = salary
#      20 else:
# ---> 21     raise ValueError('Salary must be integer and > 0')
#
# ValueError: Salary must be integer and > 0

# %%
"""
 we need encapsulation
 -> limit accessibility
 -> apply condition : salary must be int,
"""

class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError('Salary must be integer and > 0')

    def get_salary(self):
        # return value of property from object
        return  self.__salary * .9


    def set_salary(self, salary):
        # set value for proeprty of object
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError('Salary must be integer and > 0')

emp = Employee('noha', 'n@iti.com', "wriower")
print(emp.salary)
print(emp.get_salary())

# %%
# in some cases you need to define a property >> needed to be represented by special format

"""
 we need encapsulation
 -> limit accessibility
 -> apply condition : salary must be int,
"""

class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.set_salary(salary)

    def get_salary(self):
        return  self.__salary * .9


    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError('Salary must be integer and > 0')


    def salary(self):
         return  self.__salary * .9

emp = Employee('noha', 'n@iti.com', 324235)
print(emp.salary())
# Out:
# 291811.5

# %%
# in some cases you need to define a property >> needed to be represented by special format

"""
 we need encapsulation
 -> limit accessibility
 -> apply condition : salary must be int,
"""

class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.set_salary(salary)

    def get_salary(self):
        return  self.__salary * .9


    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError('Salary must be integer and > 0')

    @property #
    def salary(self):
         return  self.__salary * .9

emp = Employee('noha', 'n@iti.com', 324235)
print(emp.salary)
print(emp.get_salary())
# Out:
# 291811.5
# 291811.5

# %%
print(emp.__dict__)
# Out:
# {'name': 'noha', '_email': 'n@iti.com', '_Employee__salary': 324235}

# %%
emp.salary = "new"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 emp.salary = "new"
#
# AttributeError: property 'salary' of 'Employee' object has no setter

# %%
# in some cases you need to define a property >> needed to be represented by special format

"""
 we need encapsulation
 -> limit accessibility
 -> apply condition : salary must be int,
"""

class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.set_salary(salary)

    def get_salary(self):
        return  self.__salary * .9


    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError('Salary must be integer and > 0')

    @property #
    def salary(self):
         return  self.__salary * .9

    @salary.setter
    def salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError('Salary must be integer and > 0')

emp = Employee('noha', 'n@iti.com', 324235)
emp.salary = 10000
print(emp)
print(emp.salary)
# Out:
# <__main__.Employee object at 0x78a24430d160>
# 9000.0

# %%
# in some cases you need to define a property >> needed to be represented by special format

"""
 we need encapsulation
 -> limit accessibility
 -> apply condition : salary must be int,
"""

class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.salary = salary  # salary is propetry then call salary.setter


    @property #
    def salary(self):
         return  self.__salary * .9

    @salary.setter
    def salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError('Salary must be integer and > 0')

emp = Employee('noha', 'n@iti.com', "324235")
emp.salary = 10000
print(emp)
print(emp.salary)
# Out:
# <__main__.Employee object at 0x78a24430d940>
# 9000.0

# %%
# in some cases you need to define a property >> needed to be represented by special format

"""
 we need encapsulation
 -> limit accessibility
 -> apply condition : salary must be int,
"""

class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.salary = salary


    @property #
    def salary(self):
         return  self.__salary * .9


    @salary.setter
    def salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError('Salary must be integer and > 0')

emp = Employee('noha', 'n@iti.com', "324235")
emp.salary = 10000
print(emp)
print(emp.salary)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 31
#      28         else:
#      29             raise ValueError('Salary must be integer and > 0')
# ---> 31 emp = Employee('noha', 'n@iti.com', "324235")
#      32 emp.salary = 10000
#      33 print(emp)
#
# Cell In[23], line 11, in Employee.__init__(self, name, email, salary)
#      10 def __init__(self, name, email, salary):
# ---> 11     self.name = name
#      12     self._email = email
#      13     self.salary = salary
#
# AttributeError: property 'name' of 'Employee' object has no setter

# %%
# in some cases you need to define a property >> needed to be represented by special format

"""
 we need encapsulation
 -> limit accessibility
 -> apply condition : salary must be int,
"""

class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.salary = salary  # salary is propetry then call salary.setter


    @property #
    def salary(self):
         return  self.salary * .9

    @salary.setter
    def salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.salary = salary
        else:
            raise ValueError('Salary must be integer and > 0')

emp = Employee('noha', 'n@iti.com', 244)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[24], line 27
#      24         else:
#      25             raise ValueError('Salary must be integer and > 0')
# ---> 27 emp = Employee('noha', 'n@iti.com', 244)
#
# Cell In[24], line 13, in Employee.__init__(self, name, email, salary)
#      11 self.name = name
#      12 self._email = email
# ---> 13 self.salary = salary
#
# Cell In[24], line 23, in Employee.salary(self, salary)
#      20 @salary.setter
#      21 def salary(self, salary):
#      22     if isinstance(salary, int) and salary > 0:
# ---> 23         self.salary = salary
#      24     else:
#      25         raise ValueError('Salary must be integer and > 0')
#
# Cell In[24], line 23, in Employee.salary(self, salary)
#      20 @salary.setter
#      21 def salary(self, salary):
#      22     if isinstance(salary, int) and salary > 0:
# ---> 23         self.salary = salary
#      24     else:
#      25         raise ValueError('Salary must be integer and > 0')
#
#     [... skipping similar frames: Employee.salary at line 23 (2974 times)]
#
# Cell In[24], line 23, in Employee.salary(self, salary)
#      20 @salary.setter
#      21 def salary(self, salary):
#      22     if isinstance(salary, int) and salary > 0:
# ---> 23         self.salary = salary
#      24     else:
#      25         raise ValueError('Salary must be integer and > 0')
#
# RecursionError: maximum recursion depth exceeded

# %%
# in some cases you need to define a property >> needed to be represented by special format

"""
 we need encapsulation
 -> limit accessibility
 -> apply condition : salary must be int,
"""

class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.salary = salary  # salary is propetry then call salary.setter


    @property #
    def salary(self):
         return  self.abbass * .9

    @salary.setter
    def salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.abbass = salary
        else:
            raise ValueError('Salary must be integer and > 0')

emp = Employee('noha', 'n@iti.com', 244)

# %%
# in some cases you need to define a property >> needed to be represented by special format

"""
 we need encapsulation
 -> limit accessibility
 -> apply condition : salary must be int,
"""

class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.salary = salary  # salary is propetry then call salary.setter


    @property #
    def salary(self):
         return  self.__salary * .9

    @salary.setter
    def salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError('Salary must be integer and > 0')

emp = Employee('noha', 'n@iti.com', 244)
emp._Employee__salary = "iti" # don't do that
